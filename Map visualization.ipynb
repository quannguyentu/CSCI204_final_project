# %%
import pandas as pd
import numpy as np
# import os
# os.environ['MPLCONFIGDIR'] = os.getcwd() + "/configs/"
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon
chicago_map = gpd.read_file('chicago_police_district.shp')
df = pd.read_csv("Chicago_Crimes_2018-2019_Train - Copy.csv")
polygon = pd.read_csv("PoliceDistrictDec2012.csv")

# %%
crs = {'init' : 'epsg:4326'}
geometry = [Point(xy) for xy in zip(df["Longitude"],df["Latitude"])]
geo_df = gpd.GeoDataFrame(df,crs = crs,geometry=geometry)
geo_df.head()
# Out:
# C:\Users\nguye\anaconda3\envs\Dispatch_system_project\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#          ID Case Number           Date                Block  Beat  District  \
# 0  11855678    JC465519  1/1/2018 0:00   008XX S RACINE AVE  1232        12
# 1  11262581    JB192787  1/1/2018 0:00    023XX N MANGO AVE  2515        25
# 2  11759173    JC350601  1/1/2018 0:00  039XX W DICKENS AVE  2525        25
# 3  11759172    JC350614  1/1/2018 0:00  039XX W DICKENS AVE  2525        25
# 4  11263899    JB195577  1/1/2018 0:00   029XX N WISNER AVE  1412        14
#
#    Ward  Community Area FBI Code  X Coordinate  Y Coordinate  Year   Latitude  \
# ...

# %%
fig,ax = plt.subplots(1, figsize = (15,15))
chicago_map.plot(ax = ax, alpha = 0.4, color = "grey")
# geo_df.plot(ax = ax, marker ="o")
# Out:
# <AxesSubplot:>
